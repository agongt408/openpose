# %%
import numpy as np
from scipy import misc
import pprint as pp
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from keras.models import Model
from keras.models import load_model
from keras.layers import Dense, Activation, Input, concatenate
from keras.layers.normalization import BatchNormalization
from keras.callbacks import LearningRateScheduler, History
from keras.utils import np_utils
from keras.optimizers import Adam
from keras import backend as Keras
from keras.applications import ResNet50

from sklearn import metrics
from scipy.spatial import distance

import json
import time

# %%
import sys
sys.path.append('/home/albert/github/DenseNet/')
sys.path.append('/home/albert/github/tensorflow/')
import densenet
import triplet

# %% [markdown]
# ### Mine Triplets

# %%
CAFFE_ROOT = '/home/albert/caffe/'
train_img_dir = os.listdir(CAFFE_ROOT + 'data/market-1501/bounding_box_train')
test_img_dir = os.listdir(CAFFE_ROOT + 'data/market-1501/bounding_box_test')

# %%
train_dict = {}
train_files = []
train_labels = []

for f in train_img_dir:
    if f[-4:] == '.jpg':
        idt = int(f[0:f.index('_')])
        if not any(idt == l for l in train_labels):
            train_labels.append(idt)
            train_dict[idt] = []
        path = CAFFE_ROOT + 'data/market-1501/bounding_box_train/' + f
        train_files.append([path, idt])
        train_dict[idt].append(path)

train_labels.sort()

test_dict = {}
test_files = []
test_labels = []

for f in test_img_dir:
    if f[-4:] == '.jpg':
        idt = int(f[0:f.index('_')])
        if idt != 0 and idt != -1:
            if not any(idt == l for l in test_labels):
                test_labels.append(idt)
                test_dict[idt] = []
            path = CAFFE_ROOT + 'data/market-1501/bounding_box_test/' + f
            test_files.append([path, idt])
            test_dict[idt].append(path)
        
test_labels.sort()

# %%
im = misc.imread(train_files[0][0])
plt.imshow(im)

# %%
print np.mean(im)
# Out:
# 140.483439128

# %%
im_preprocess = densenet.preprocess_input(im.astype(np.float64))

# %%
print np.mean(im_preprocess.astype(np.uint8))
# Out:
# 33.4220377604

# %%
print im_preprocess.max()
# Out:
# 2.568037

# %%
print train_files[0]
# Out:
# ['/home/albert/caffe/data/market-1501/bounding_box_train/0575_c6s2_004068_01.jpg', 575]

# %%
print test_files[0]
# Out:
# ['/home/albert/caffe/data/market-1501/bounding_box_test/0152_c2s1_024601_02.jpg', 152]

# %% [markdown]
# ### Train Network

# %%
# Number of identities
P_param = 8
# Number of images per identity
K_param = 4

# %%
def makeGaussian(shape, fwhm = 3, center=None):
    """ Make a square gaussian kernel.

    size is the length of a side of the square
    fwhm is full-width-half-maximum, which
    can be thought of as an effective radius.
    """

    x = np.arange(0, np.array(shape).max(), 1, float)
    y = x[:,np.newaxis]

    if center is None:
        x0 = y0 = size // 2
    else:
        x0 = center[0]
        y0 = center[1]

    return np.exp(-4*np.log(2) * ((x-x0)**2 + (y-y0)**2) / fwhm**2)[0:shape[0], 0:shape[1]]

# %%
def overlay_keypoints(img_path, train=False):
    if img_path.find('/') > -1:
        root = img_path[len(img_path) - img_path[::-1].index('/'):-4:]
    else:
        root = img_path[0:img_path.index('.')]
    
    img = misc.imread(img_path)
    htmp = np.zeros((128,64)).astype(np.float32)
    
    if train:
        keypoint_path = CAFFE_ROOT + \
                    'data/market-1501/train_openpose/train_keypoints/%s_keypoints.json' % root
    else:
        keypoint_path = CAFFE_ROOT + \
                    'data/market-1501/test_openpose/test_keypoints/%s_keypoints.json' % root
    with open(keypoint_path) as data_file:    
        data = json.load(data_file)
    for person in range(len(data['people'])):
        for i in range(0, len(data['people'][person]['pose_keypoints']), 3):
            x_key = data['people'][person]['pose_keypoints'][i]
            y_key = data['people'][person]['pose_keypoints'][i + 1]
            c_key = data['people'][person]['pose_keypoints'][i + 2]
            if not (x_key == 0 and y_key == 0):
                htmp += makeGaussian((128,64), fwhm=10, center=(x_key, y_key))

    if htmp.max() > 0.0:
        htmp = np.array([[3*[j/htmp.max()] for j in row] for row in htmp.tolist()])
    else:
        htmp = np.array([[3*[j] for j in row] for row in htmp.tolist()])
    return (img*htmp).astype(np.uint8)

# %%
def output_batch_generator(files_dict, labels, P=P_param, K=K_param):
    while True:
        batch_b = []
        batch_k = []
        idt_choice = np.random.choice(labels, P, replace=False)
        for p in range(len(idt_choice)):
            if K > len(files_dict[idt_choice[p]]):
                k_choice = np.random.choice(range(len(files_dict[idt_choice[p]])), K, replace=True)
            else:
                k_choice = np.random.choice(range(len(files_dict[idt_choice[p]])), K, replace=False)            
#             print k_choice, p
            for k in k_choice:
                img_path = files_dict[idt_choice[p]][k]
                img = misc.imread(img_path).astype(np.float64)
                batch_b.append(img.tolist())
                batch_k.append(overlay_keypoints(img_path, train=True).tolist())
        yield {'input_1_b' : np.array(batch_b, dtype=np.uint8), 'input_1_k' : np.array(batch_k, dtype=np.uint8)}, \
                {'final_output' : np.zeros((P*K, 128))}

# %%
start = time.time()
htmp_test = overlay_keypoints(CAFFE_ROOT + \
                'data/market-1501/bounding_box_train/%s.jpg' % '1496_c4s6_021591_07', train=True)
print time.time() - start
# Out:
# 0.0580999851227

# %%
start = time.time()
train_batch = output_batch_generator(train_dict, train_labels).next()
print time.time() - start
# Out:
# 2.29974484444

# %%
plt.figure(figsize=(15,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(train_batch[0]['input_1_b'][i])
    plt.axis('off')
plt.show()
plt.figure(figsize=(15,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(train_batch[0]['input_1_k'][i])
    plt.axis('off')
plt.show()

# %%
def log1p(x):
    return Keras.log(1 + Keras.exp(x))

def dist(x1, x2):
    return Keras.sum(Keras.abs(x1 - x2), axis=1)

def triplet_loss(y_true, y_pred, margin=0.5, P=P_param, K=K_param, output_dim = 128):
    embeddings = Keras.reshape(y_pred, (-1, output_dim))

    loss = tf.Variable(1, dtype=tf.float32)

    for i in range(P):
        for a in range(K):
            pred_anchor = embeddings[i*K + a]
            hard_pos = Keras.max(dist(pred_anchor, embeddings[i*K:(i + 1)*K]))
            hard_neg = Keras.min(dist(pred_anchor, Keras.concatenate([embeddings[0:i*K],
                                                                      embeddings[(i + 1)*K:]], 0)))
            loss += margin + hard_pos - hard_neg
    return loss

# %%
def evaluate_rank(net, rank, all_embeddings, all_identities, files_arr, test_iter=1000, shape=(128,64), train=False):
    correct = 0
    f_choice = np.random.choice(range(len(files_arr)), np.minimum(test_iter, len(files_arr)), replace=False)
    for f in f_choice:
        query_path = files_arr[f][0]
        query_img = misc.imread(query_path)
        query_embedding = net.predict({'input_1_b' : query_img.reshape(1, shape[0], shape[1], 3), 
                                       'input_1_k' : overlay_keypoints(query_path, train=train).reshape(1, shape[0], shape[1], 3)})
        distance_vectors = np.squeeze(np.abs(all_embeddings - query_embedding))
        distance = np.sum(distance_vectors, axis=1)
        top_inds = distance.argsort()[:rank+1]
        output_classes = np.array(all_identities)[top_inds].astype(np.uint16)
        
        i = 0
        for c in output_classes:
            if c == int(files_arr[f][1]):
                i += 1
        if i > 1:
            correct += 1
    return float(correct)/test_iter

# %%
def pos_pair_generator(files_dict):
    while True:
        idt = np.random.choice(files_dict.keys(), 1, replace=False)[0]
        sample_choice = np.random.choice(range(len(files_dict[idt])), np.minimum(2, len(files_dict[idt])), replace=False)
        pair = [files_dict[idt][p] for p in sample_choice]
        yield pair

# %%
def neg_pair_generator(files_dict):
    while True:
        idt_choice = np.random.choice(files_dict.keys(), 2, replace=False)
        pair = []
        for idt in idt_choice:
            sample = np.random.choice(range(len(files_dict[idt])), 1, replace=False)[0]
            pair.append(files_dict[idt][sample])
        yield pair

# %%
def evaluate_dist(model, generator, n_pairs=1000, train=False):
    distances = []
    for t in range(n_pairs):
        pair = generator.next()   
        predict = [model.predict({'input_1_b' : misc.imread(pair[i]).reshape(1,128,64,3), 
                                  'input_1_k' : overlay_keypoints(pair[i], train=train).reshape(1,128,64,3)}) for i in range(2)]
        dist = distance.cosine(predict[0], predict[1])
        distances.append(dist)
    return distances

# %% [markdown]
# According to the triplet loss paper, use an adaptive learning rate decay that is constant at first, then decays exponentially.

# %%
# https://medium.com/towards-data-science/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1
def step_decay(epoch):
    initial_lr = 0.0003
    drop = 0.5
    epochs_drop = 20
    lrate = initial_lr * np.power(drop,  
           np.floor((1+epoch)/epochs_drop))
    return lrate

def step_decay_cont(epoch, init_epoch, init_lr=0.0003):
    drop = 0.5
    epochs_drop = 20.0
    lrate = init_lr * np.power(drop,  
           np.floor((1 + epoch + init_epoch)/epochs_drop))
    return lrate

# %%
lr = []
for i in range(100):
    lr.append(step_decay(i))
plt.plot(np.arange(100), lr)

# %%
lr = []
for i in range(4):
    for j in range(25):
        lr.append(step_decay_cont(j, 25*i, 0.0003))
plt.plot(np.arange(100), lr)

# %%
def get_score(model, files_dict, files_arr, file_root, score, iterations, hist=False, train=True):
    all_embeddings = []
    all_identities = []
    z = 1
    start = time.time()
    for idt in files_dict.keys():
        for f in files_dict[idt]:
            img = misc.imread(f)
            predict = model.predict({'input_1_b' : img.reshape(1, 128, 64, 3), 
                                 'input_1_k' : overlay_keypoints(f, train=train).reshape(1, 128, 64, 3)})
#             print predict
            all_embeddings.append(predict)
            all_identities.append(idt)
            if z % 1000 == 0:
                print z, time.time() - start
            z += 1

    for rank in [1,5,20]:
        rank_arr = []
        for x in range(3):
            rank_score = evaluate_rank(model, rank, all_embeddings, 
                                       all_identities, files_arr, test_iter=1000, train=train)
            rank_arr.append(rank_score)
        score['rank%d' % rank][iterations] = rank_arr
    
    pos_generator = pos_pair_generator(files_dict)
    neg_generator = neg_pair_generator(files_dict)
    
    pos_distance = evaluate_dist(model, pos_generator, train=train)
    score['pos_distance'][iterations] = pos_distance
    
    neg_distance = evaluate_dist(model, neg_generator, train=train)
    score['neg_distance'][iterations] = neg_distance
    
    score['precision'][iterations] = []
    score['recall'][iterations] = []
    score['matt_coef'][iterations] = []
    
    for thresh in np.linspace(0, np.max(np.array(pos_distance + neg_distance)), 101)[1:]:
        true = np.ones(len(pos_distance)).tolist() + np.zeros(len(neg_distance)).tolist()
        pred_pos = [int(d < thresh) for d in pos_distance]
        pred_neg = [int(d < thresh) for d in neg_distance]
        pred = pred_pos + pred_neg

        score['precision'][iterations].append(metrics.precision_score(true, pred))
        score['recall'][iterations].append(metrics.recall_score(true, pred))
        score['matt_coef'][iterations].append(metrics.matthews_corrcoef(true, pred))
    
    if hist:
        score['loss'] += history.history['loss']
    
    file_name = file_root + '_' + str(iterations) + '.h5'
    score['file_name'][iterations] = file_name
    
    return score

# %% [markdown]
# Replace top layer of DenseNet with a FC layer (1024) with batch normalization and ReLU and a FC layer (128). Train with all layers as learnable for 50 epochs with learning rate decay 1e-6.

# %%
# https://keras.io/getting-started/functional-api-guide/#multi-input-and-multi-output-models
base_model = load_model('/home/albert/github/tensorflow/models/densenet_triplet_margin_3/densenet_triplet_margin_3_5000.h5',
                        custom_objects={'triplet_loss':triplet_loss})
keypoint_model = load_model('/home/albert/github/tensorflow/models/densenet_triplet_keypoint/densenet_triplet_keypoint_3000.h5',
                        custom_objects={'triplet_loss':triplet_loss})
for layer in base_model.layers:
    layer.name = layer.name + '_b'
for layer in keypoint_model.layers:
    layer.name = layer.name + '_k'

# %%
base_model.outputs = [base_model.layers[-1].output]
base_model.layers[-1].outbound_nodes = []
keypoint_model.outputs = [keypoint_model.layers[-1].output]
keypoint_model.layers[-1].outbound_nodes = []

x = concatenate([base_model.outputs[0], keypoint_model.outputs[0]])
x = Dense(1024)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
predictions = Dense(128, name='final_output')(x)

# %%
model = Model(inputs=[base_model.input, keypoint_model.input], outputs=predictions)
model.compile(loss=triplet_loss, optimizer=Adam(lr=0.0003, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1_b (InputLayer)           (None, 128, 64, 3)    0
# ____________________________________________________________________________________________________
# input_1_k (InputLayer)           (None, 128, 64, 3)    0
# ____________________________________________________________________________________________________
# conv2d_1_b (Conv2D)              (None, 64, 32, 64)    9408        input_1_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_1_k (Conv2D)              (None, 64, 32, 64)    9408        input_1_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1_b (BatchNo (None, 64, 32, 64)    256         conv2d_1_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1_k (BatchNo (None, 64, 32, 64)    256         conv2d_1_k[0][0]
# ____________________________________________________________________________________________________
# activation_1_b (Activation)      (None, 64, 32, 64)    0           batch_normalization_1_b[0][0]
# ____________________________________________________________________________________________________
# activation_1_k (Activation)      (None, 64, 32, 64)    0           batch_normalization_1_k[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1_b (MaxPooling2D) (None, 32, 16, 64)    0           activation_1_b[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1_k (MaxPooling2D) (None, 32, 16, 64)    0           activation_1_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2_b (BatchNo (None, 32, 16, 64)    256         max_pooling2d_1_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2_k (BatchNo (None, 32, 16, 64)    256         max_pooling2d_1_k[0][0]
# ____________________________________________________________________________________________________
# activation_2_b (Activation)      (None, 32, 16, 64)    0           batch_normalization_2_b[0][0]
# ____________________________________________________________________________________________________
# activation_2_k (Activation)      (None, 32, 16, 64)    0           batch_normalization_2_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_2_b (Conv2D)              (None, 32, 16, 128)   8192        activation_2_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_2_k (Conv2D)              (None, 32, 16, 128)   8192        activation_2_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3_b (BatchNo (None, 32, 16, 128)   512         conv2d_2_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3_k (BatchNo (None, 32, 16, 128)   512         conv2d_2_k[0][0]
# ____________________________________________________________________________________________________
# activation_3_b (Activation)      (None, 32, 16, 128)   0           batch_normalization_3_b[0][0]
# ____________________________________________________________________________________________________
# activation_3_k (Activation)      (None, 32, 16, 128)   0           batch_normalization_3_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_3_b (Conv2D)              (None, 32, 16, 32)    36864       activation_3_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_3_k (Conv2D)              (None, 32, 16, 32)    36864       activation_3_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_1_b (Concatenate)    (None, 32, 16, 96)    0           max_pooling2d_1_b[0][0]
#                                                                    conv2d_3_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_1_k (Concatenate)    (None, 32, 16, 96)    0           max_pooling2d_1_k[0][0]
#                                                                    conv2d_3_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4_b (BatchNo (None, 32, 16, 96)    384         concatenate_1_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4_k (BatchNo (None, 32, 16, 96)    384         concatenate_1_k[0][0]
# ____________________________________________________________________________________________________
# activation_4_b (Activation)      (None, 32, 16, 96)    0           batch_normalization_4_b[0][0]
# ____________________________________________________________________________________________________
# activation_4_k (Activation)      (None, 32, 16, 96)    0           batch_normalization_4_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_4_b (Conv2D)              (None, 32, 16, 128)   12288       activation_4_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_4_k (Conv2D)              (None, 32, 16, 128)   12288       activation_4_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5_b (BatchNo (None, 32, 16, 128)   512         conv2d_4_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5_k (BatchNo (None, 32, 16, 128)   512         conv2d_4_k[0][0]
# ____________________________________________________________________________________________________
# activation_5_b (Activation)      (None, 32, 16, 128)   0           batch_normalization_5_b[0][0]
# ____________________________________________________________________________________________________
# activation_5_k (Activation)      (None, 32, 16, 128)   0           batch_normalization_5_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_5_b (Conv2D)              (None, 32, 16, 32)    36864       activation_5_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_5_k (Conv2D)              (None, 32, 16, 32)    36864       activation_5_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_2_b (Concatenate)    (None, 32, 16, 128)   0           concatenate_1_b[0][0]
#                                                                    conv2d_5_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_2_k (Concatenate)    (None, 32, 16, 128)   0           concatenate_1_k[0][0]
#                                                                    conv2d_5_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6_b (BatchNo (None, 32, 16, 128)   512         concatenate_2_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6_k (BatchNo (None, 32, 16, 128)   512         concatenate_2_k[0][0]
# ____________________________________________________________________________________________________
# activation_6_b (Activation)      (None, 32, 16, 128)   0           batch_normalization_6_b[0][0]
# ____________________________________________________________________________________________________
# activation_6_k (Activation)      (None, 32, 16, 128)   0           batch_normalization_6_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_6_b (Conv2D)              (None, 32, 16, 128)   16384       activation_6_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_6_k (Conv2D)              (None, 32, 16, 128)   16384       activation_6_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7_b (BatchNo (None, 32, 16, 128)   512         conv2d_6_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7_k (BatchNo (None, 32, 16, 128)   512         conv2d_6_k[0][0]
# ____________________________________________________________________________________________________
# activation_7_b (Activation)      (None, 32, 16, 128)   0           batch_normalization_7_b[0][0]
# ____________________________________________________________________________________________________
# activation_7_k (Activation)      (None, 32, 16, 128)   0           batch_normalization_7_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_7_b (Conv2D)              (None, 32, 16, 32)    36864       activation_7_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_7_k (Conv2D)              (None, 32, 16, 32)    36864       activation_7_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_3_b (Concatenate)    (None, 32, 16, 160)   0           concatenate_2_b[0][0]
#                                                                    conv2d_7_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_3_k (Concatenate)    (None, 32, 16, 160)   0           concatenate_2_k[0][0]
#                                                                    conv2d_7_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8_b (BatchNo (None, 32, 16, 160)   640         concatenate_3_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8_k (BatchNo (None, 32, 16, 160)   640         concatenate_3_k[0][0]
# ____________________________________________________________________________________________________
# activation_8_b (Activation)      (None, 32, 16, 160)   0           batch_normalization_8_b[0][0]
# ____________________________________________________________________________________________________
# activation_8_k (Activation)      (None, 32, 16, 160)   0           batch_normalization_8_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_8_b (Conv2D)              (None, 32, 16, 128)   20480       activation_8_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_8_k (Conv2D)              (None, 32, 16, 128)   20480       activation_8_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9_b (BatchNo (None, 32, 16, 128)   512         conv2d_8_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9_k (BatchNo (None, 32, 16, 128)   512         conv2d_8_k[0][0]
# ____________________________________________________________________________________________________
# activation_9_b (Activation)      (None, 32, 16, 128)   0           batch_normalization_9_b[0][0]
# ____________________________________________________________________________________________________
# activation_9_k (Activation)      (None, 32, 16, 128)   0           batch_normalization_9_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_9_b (Conv2D)              (None, 32, 16, 32)    36864       activation_9_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_9_k (Conv2D)              (None, 32, 16, 32)    36864       activation_9_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_4_b (Concatenate)    (None, 32, 16, 192)   0           concatenate_3_b[0][0]
#                                                                    conv2d_9_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_4_k (Concatenate)    (None, 32, 16, 192)   0           concatenate_3_k[0][0]
#                                                                    conv2d_9_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10_b (BatchN (None, 32, 16, 192)   768         concatenate_4_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10_k (BatchN (None, 32, 16, 192)   768         concatenate_4_k[0][0]
# ____________________________________________________________________________________________________
# activation_10_b (Activation)     (None, 32, 16, 192)   0           batch_normalization_10_b[0][0]
# ____________________________________________________________________________________________________
# activation_10_k (Activation)     (None, 32, 16, 192)   0           batch_normalization_10_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_10_b (Conv2D)             (None, 32, 16, 128)   24576       activation_10_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_10_k (Conv2D)             (None, 32, 16, 128)   24576       activation_10_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11_b (BatchN (None, 32, 16, 128)   512         conv2d_10_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11_k (BatchN (None, 32, 16, 128)   512         conv2d_10_k[0][0]
# ____________________________________________________________________________________________________
# activation_11_b (Activation)     (None, 32, 16, 128)   0           batch_normalization_11_b[0][0]
# ____________________________________________________________________________________________________
# activation_11_k (Activation)     (None, 32, 16, 128)   0           batch_normalization_11_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_11_b (Conv2D)             (None, 32, 16, 32)    36864       activation_11_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_11_k (Conv2D)             (None, 32, 16, 32)    36864       activation_11_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_5_b (Concatenate)    (None, 32, 16, 224)   0           concatenate_4_b[0][0]
#                                                                    conv2d_11_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_5_k (Concatenate)    (None, 32, 16, 224)   0           concatenate_4_k[0][0]
#                                                                    conv2d_11_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12_b (BatchN (None, 32, 16, 224)   896         concatenate_5_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12_k (BatchN (None, 32, 16, 224)   896         concatenate_5_k[0][0]
# ____________________________________________________________________________________________________
# activation_12_b (Activation)     (None, 32, 16, 224)   0           batch_normalization_12_b[0][0]
# ____________________________________________________________________________________________________
# activation_12_k (Activation)     (None, 32, 16, 224)   0           batch_normalization_12_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_12_b (Conv2D)             (None, 32, 16, 128)   28672       activation_12_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_12_k (Conv2D)             (None, 32, 16, 128)   28672       activation_12_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13_b (BatchN (None, 32, 16, 128)   512         conv2d_12_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13_k (BatchN (None, 32, 16, 128)   512         conv2d_12_k[0][0]
# ____________________________________________________________________________________________________
# activation_13_b (Activation)     (None, 32, 16, 128)   0           batch_normalization_13_b[0][0]
# ____________________________________________________________________________________________________
# activation_13_k (Activation)     (None, 32, 16, 128)   0           batch_normalization_13_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_13_b (Conv2D)             (None, 32, 16, 32)    36864       activation_13_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_13_k (Conv2D)             (None, 32, 16, 32)    36864       activation_13_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_6_b (Concatenate)    (None, 32, 16, 256)   0           concatenate_5_b[0][0]
#                                                                    conv2d_13_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_6_k (Concatenate)    (None, 32, 16, 256)   0           concatenate_5_k[0][0]
#                                                                    conv2d_13_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14_b (BatchN (None, 32, 16, 256)   1024        concatenate_6_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14_k (BatchN (None, 32, 16, 256)   1024        concatenate_6_k[0][0]
# ____________________________________________________________________________________________________
# activation_14_b (Activation)     (None, 32, 16, 256)   0           batch_normalization_14_b[0][0]
# ____________________________________________________________________________________________________
# activation_14_k (Activation)     (None, 32, 16, 256)   0           batch_normalization_14_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_14_b (Conv2D)             (None, 32, 16, 128)   32768       activation_14_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_14_k (Conv2D)             (None, 32, 16, 128)   32768       activation_14_k[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_1_b (AveragePo (None, 16, 8, 128)    0           conv2d_14_b[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_1_k (AveragePo (None, 16, 8, 128)    0           conv2d_14_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15_b (BatchN (None, 16, 8, 128)    512         average_pooling2d_1_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15_k (BatchN (None, 16, 8, 128)    512         average_pooling2d_1_k[0][0]
# ____________________________________________________________________________________________________
# activation_15_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_15_b[0][0]
# ____________________________________________________________________________________________________
# activation_15_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_15_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_15_b (Conv2D)             (None, 16, 8, 128)    16384       activation_15_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_15_k (Conv2D)             (None, 16, 8, 128)    16384       activation_15_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16_b (BatchN (None, 16, 8, 128)    512         conv2d_15_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16_k (BatchN (None, 16, 8, 128)    512         conv2d_15_k[0][0]
# ____________________________________________________________________________________________________
# activation_16_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_16_b[0][0]
# ____________________________________________________________________________________________________
# activation_16_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_16_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_16_b (Conv2D)             (None, 16, 8, 32)     36864       activation_16_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_16_k (Conv2D)             (None, 16, 8, 32)     36864       activation_16_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_7_b (Concatenate)    (None, 16, 8, 160)    0           average_pooling2d_1_b[0][0]
#                                                                    conv2d_16_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_7_k (Concatenate)    (None, 16, 8, 160)    0           average_pooling2d_1_k[0][0]
#                                                                    conv2d_16_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_17_b (BatchN (None, 16, 8, 160)    640         concatenate_7_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_17_k (BatchN (None, 16, 8, 160)    640         concatenate_7_k[0][0]
# ____________________________________________________________________________________________________
# activation_17_b (Activation)     (None, 16, 8, 160)    0           batch_normalization_17_b[0][0]
# ____________________________________________________________________________________________________
# activation_17_k (Activation)     (None, 16, 8, 160)    0           batch_normalization_17_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_17_b (Conv2D)             (None, 16, 8, 128)    20480       activation_17_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_17_k (Conv2D)             (None, 16, 8, 128)    20480       activation_17_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_18_b (BatchN (None, 16, 8, 128)    512         conv2d_17_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_18_k (BatchN (None, 16, 8, 128)    512         conv2d_17_k[0][0]
# ____________________________________________________________________________________________________
# activation_18_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_18_b[0][0]
# ____________________________________________________________________________________________________
# activation_18_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_18_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_18_b (Conv2D)             (None, 16, 8, 32)     36864       activation_18_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_18_k (Conv2D)             (None, 16, 8, 32)     36864       activation_18_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_8_b (Concatenate)    (None, 16, 8, 192)    0           concatenate_7_b[0][0]
#                                                                    conv2d_18_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_8_k (Concatenate)    (None, 16, 8, 192)    0           concatenate_7_k[0][0]
#                                                                    conv2d_18_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_19_b (BatchN (None, 16, 8, 192)    768         concatenate_8_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_19_k (BatchN (None, 16, 8, 192)    768         concatenate_8_k[0][0]
# ____________________________________________________________________________________________________
# activation_19_b (Activation)     (None, 16, 8, 192)    0           batch_normalization_19_b[0][0]
# ____________________________________________________________________________________________________
# activation_19_k (Activation)     (None, 16, 8, 192)    0           batch_normalization_19_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_19_b (Conv2D)             (None, 16, 8, 128)    24576       activation_19_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_19_k (Conv2D)             (None, 16, 8, 128)    24576       activation_19_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_20_b (BatchN (None, 16, 8, 128)    512         conv2d_19_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_20_k (BatchN (None, 16, 8, 128)    512         conv2d_19_k[0][0]
# ____________________________________________________________________________________________________
# activation_20_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_20_b[0][0]
# ____________________________________________________________________________________________________
# activation_20_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_20_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_20_b (Conv2D)             (None, 16, 8, 32)     36864       activation_20_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_20_k (Conv2D)             (None, 16, 8, 32)     36864       activation_20_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_9_b (Concatenate)    (None, 16, 8, 224)    0           concatenate_8_b[0][0]
#                                                                    conv2d_20_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_9_k (Concatenate)    (None, 16, 8, 224)    0           concatenate_8_k[0][0]
#                                                                    conv2d_20_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_21_b (BatchN (None, 16, 8, 224)    896         concatenate_9_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_21_k (BatchN (None, 16, 8, 224)    896         concatenate_9_k[0][0]
# ____________________________________________________________________________________________________
# activation_21_b (Activation)     (None, 16, 8, 224)    0           batch_normalization_21_b[0][0]
# ____________________________________________________________________________________________________
# activation_21_k (Activation)     (None, 16, 8, 224)    0           batch_normalization_21_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_21_b (Conv2D)             (None, 16, 8, 128)    28672       activation_21_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_21_k (Conv2D)             (None, 16, 8, 128)    28672       activation_21_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_22_b (BatchN (None, 16, 8, 128)    512         conv2d_21_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_22_k (BatchN (None, 16, 8, 128)    512         conv2d_21_k[0][0]
# ____________________________________________________________________________________________________
# activation_22_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_22_b[0][0]
# ____________________________________________________________________________________________________
# activation_22_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_22_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_22_b (Conv2D)             (None, 16, 8, 32)     36864       activation_22_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_22_k (Conv2D)             (None, 16, 8, 32)     36864       activation_22_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_10_b (Concatenate)   (None, 16, 8, 256)    0           concatenate_9_b[0][0]
#                                                                    conv2d_22_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_10_k (Concatenate)   (None, 16, 8, 256)    0           concatenate_9_k[0][0]
#                                                                    conv2d_22_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_23_b (BatchN (None, 16, 8, 256)    1024        concatenate_10_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_23_k (BatchN (None, 16, 8, 256)    1024        concatenate_10_k[0][0]
# ____________________________________________________________________________________________________
# activation_23_b (Activation)     (None, 16, 8, 256)    0           batch_normalization_23_b[0][0]
# ____________________________________________________________________________________________________
# activation_23_k (Activation)     (None, 16, 8, 256)    0           batch_normalization_23_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_23_b (Conv2D)             (None, 16, 8, 128)    32768       activation_23_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_23_k (Conv2D)             (None, 16, 8, 128)    32768       activation_23_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_24_b (BatchN (None, 16, 8, 128)    512         conv2d_23_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_24_k (BatchN (None, 16, 8, 128)    512         conv2d_23_k[0][0]
# ____________________________________________________________________________________________________
# activation_24_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_24_b[0][0]
# ____________________________________________________________________________________________________
# activation_24_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_24_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_24_b (Conv2D)             (None, 16, 8, 32)     36864       activation_24_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_24_k (Conv2D)             (None, 16, 8, 32)     36864       activation_24_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_11_b (Concatenate)   (None, 16, 8, 288)    0           concatenate_10_b[0][0]
#                                                                    conv2d_24_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_11_k (Concatenate)   (None, 16, 8, 288)    0           concatenate_10_k[0][0]
#                                                                    conv2d_24_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_25_b (BatchN (None, 16, 8, 288)    1152        concatenate_11_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_25_k (BatchN (None, 16, 8, 288)    1152        concatenate_11_k[0][0]
# ____________________________________________________________________________________________________
# activation_25_b (Activation)     (None, 16, 8, 288)    0           batch_normalization_25_b[0][0]
# ____________________________________________________________________________________________________
# activation_25_k (Activation)     (None, 16, 8, 288)    0           batch_normalization_25_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_25_b (Conv2D)             (None, 16, 8, 128)    36864       activation_25_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_25_k (Conv2D)             (None, 16, 8, 128)    36864       activation_25_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_26_b (BatchN (None, 16, 8, 128)    512         conv2d_25_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_26_k (BatchN (None, 16, 8, 128)    512         conv2d_25_k[0][0]
# ____________________________________________________________________________________________________
# activation_26_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_26_b[0][0]
# ____________________________________________________________________________________________________
# activation_26_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_26_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_26_b (Conv2D)             (None, 16, 8, 32)     36864       activation_26_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_26_k (Conv2D)             (None, 16, 8, 32)     36864       activation_26_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_12_b (Concatenate)   (None, 16, 8, 320)    0           concatenate_11_b[0][0]
#                                                                    conv2d_26_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_12_k (Concatenate)   (None, 16, 8, 320)    0           concatenate_11_k[0][0]
#                                                                    conv2d_26_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_27_b (BatchN (None, 16, 8, 320)    1280        concatenate_12_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_27_k (BatchN (None, 16, 8, 320)    1280        concatenate_12_k[0][0]
# ____________________________________________________________________________________________________
# activation_27_b (Activation)     (None, 16, 8, 320)    0           batch_normalization_27_b[0][0]
# ____________________________________________________________________________________________________
# activation_27_k (Activation)     (None, 16, 8, 320)    0           batch_normalization_27_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_27_b (Conv2D)             (None, 16, 8, 128)    40960       activation_27_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_27_k (Conv2D)             (None, 16, 8, 128)    40960       activation_27_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_28_b (BatchN (None, 16, 8, 128)    512         conv2d_27_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_28_k (BatchN (None, 16, 8, 128)    512         conv2d_27_k[0][0]
# ____________________________________________________________________________________________________
# activation_28_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_28_b[0][0]
# ____________________________________________________________________________________________________
# activation_28_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_28_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_28_b (Conv2D)             (None, 16, 8, 32)     36864       activation_28_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_28_k (Conv2D)             (None, 16, 8, 32)     36864       activation_28_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_13_b (Concatenate)   (None, 16, 8, 352)    0           concatenate_12_b[0][0]
#                                                                    conv2d_28_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_13_k (Concatenate)   (None, 16, 8, 352)    0           concatenate_12_k[0][0]
#                                                                    conv2d_28_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_29_b (BatchN (None, 16, 8, 352)    1408        concatenate_13_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_29_k (BatchN (None, 16, 8, 352)    1408        concatenate_13_k[0][0]
# ____________________________________________________________________________________________________
# activation_29_b (Activation)     (None, 16, 8, 352)    0           batch_normalization_29_b[0][0]
# ____________________________________________________________________________________________________
# activation_29_k (Activation)     (None, 16, 8, 352)    0           batch_normalization_29_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_29_b (Conv2D)             (None, 16, 8, 128)    45056       activation_29_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_29_k (Conv2D)             (None, 16, 8, 128)    45056       activation_29_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_30_b (BatchN (None, 16, 8, 128)    512         conv2d_29_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_30_k (BatchN (None, 16, 8, 128)    512         conv2d_29_k[0][0]
# ____________________________________________________________________________________________________
# activation_30_b (Activation)     (None, 16, 8, 128)    0           batch_normalization_30_b[0][0]
# ____________________________________________________________________________________________________
# activation_30_k (Activation)     (None, 16, 8, 128)    0           batch_normalization_30_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_30_b (Conv2D)             (None, 16, 8, 32)     36864       activation_30_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_30_k (Conv2D)             (None, 16, 8, 32)     36864       activation_30_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_14_b (Concatenate)   (None, 16, 8, 384)    0           concatenate_13_b[0][0]
#                                                                    conv2d_30_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_14_k (Concatenate)   (None, 16, 8, 384)    0           concatenate_13_k[0][0]
#                                                                    conv2d_30_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_31_b (BatchN (None, 16, 8, 384)    1536        concatenate_14_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_31_k (BatchN (None, 16, 8, 384)    1536        concatenate_14_k[0][0]
# ____________________________________________________________________________________________________
# activation_31_b (Activation)     (None, 16, 8, 384)    0           batch_normalization_31_b[0][0]
# ____________________________________________________________________________________________________
# activation_31_k (Activation)     (None, 16, 8, 384)    0           batch_normalization_31_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_31_b (Conv2D)             (None, 16, 8, 128)    49152       activation_31_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_31_k (Conv2D)             (None, 16, 8, 128)    49152       activation_31_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_32_b (BatchN (None, 16, 8, 128)    512         conv2d_31_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_32_k (BatchN (None, 16, 8, 128)    512         conv2d_31_k[0][0]
# ____________________________________________________________________________________________________
# ...
# ____________________________________________________________________________________________________
# activation_113_b (Activation)    (None, 4, 2, 896)     0           batch_normalization_113_b[0][0]
# ____________________________________________________________________________________________________
# activation_113_k (Activation)    (None, 4, 2, 896)     0           batch_normalization_113_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_113_b (Conv2D)            (None, 4, 2, 128)     114688      activation_113_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_113_k (Conv2D)            (None, 4, 2, 128)     114688      activation_113_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_114_b (Batch (None, 4, 2, 128)     512         conv2d_113_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_114_k (Batch (None, 4, 2, 128)     512         conv2d_113_k[0][0]
# ____________________________________________________________________________________________________
# activation_114_b (Activation)    (None, 4, 2, 128)     0           batch_normalization_114_b[0][0]
# ____________________________________________________________________________________________________
# activation_114_k (Activation)    (None, 4, 2, 128)     0           batch_normalization_114_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_114_b (Conv2D)            (None, 4, 2, 32)      36864       activation_114_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_114_k (Conv2D)            (None, 4, 2, 32)      36864       activation_114_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_55_b (Concatenate)   (None, 4, 2, 928)     0           concatenate_54_b[0][0]
#                                                                    conv2d_114_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_55_k (Concatenate)   (None, 4, 2, 928)     0           concatenate_54_k[0][0]
#                                                                    conv2d_114_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_115_b (Batch (None, 4, 2, 928)     3712        concatenate_55_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_115_k (Batch (None, 4, 2, 928)     3712        concatenate_55_k[0][0]
# ____________________________________________________________________________________________________
# activation_115_b (Activation)    (None, 4, 2, 928)     0           batch_normalization_115_b[0][0]
# ____________________________________________________________________________________________________
# activation_115_k (Activation)    (None, 4, 2, 928)     0           batch_normalization_115_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_115_b (Conv2D)            (None, 4, 2, 128)     118784      activation_115_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_115_k (Conv2D)            (None, 4, 2, 128)     118784      activation_115_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_116_b (Batch (None, 4, 2, 128)     512         conv2d_115_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_116_k (Batch (None, 4, 2, 128)     512         conv2d_115_k[0][0]
# ____________________________________________________________________________________________________
# activation_116_b (Activation)    (None, 4, 2, 128)     0           batch_normalization_116_b[0][0]
# ____________________________________________________________________________________________________
# activation_116_k (Activation)    (None, 4, 2, 128)     0           batch_normalization_116_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_116_b (Conv2D)            (None, 4, 2, 32)      36864       activation_116_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_116_k (Conv2D)            (None, 4, 2, 32)      36864       activation_116_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_56_b (Concatenate)   (None, 4, 2, 960)     0           concatenate_55_b[0][0]
#                                                                    conv2d_116_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_56_k (Concatenate)   (None, 4, 2, 960)     0           concatenate_55_k[0][0]
#                                                                    conv2d_116_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_117_b (Batch (None, 4, 2, 960)     3840        concatenate_56_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_117_k (Batch (None, 4, 2, 960)     3840        concatenate_56_k[0][0]
# ____________________________________________________________________________________________________
# activation_117_b (Activation)    (None, 4, 2, 960)     0           batch_normalization_117_b[0][0]
# ____________________________________________________________________________________________________
# activation_117_k (Activation)    (None, 4, 2, 960)     0           batch_normalization_117_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_117_b (Conv2D)            (None, 4, 2, 128)     122880      activation_117_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_117_k (Conv2D)            (None, 4, 2, 128)     122880      activation_117_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_118_b (Batch (None, 4, 2, 128)     512         conv2d_117_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_118_k (Batch (None, 4, 2, 128)     512         conv2d_117_k[0][0]
# ____________________________________________________________________________________________________
# activation_118_b (Activation)    (None, 4, 2, 128)     0           batch_normalization_118_b[0][0]
# ____________________________________________________________________________________________________
# activation_118_k (Activation)    (None, 4, 2, 128)     0           batch_normalization_118_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_118_b (Conv2D)            (None, 4, 2, 32)      36864       activation_118_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_118_k (Conv2D)            (None, 4, 2, 32)      36864       activation_118_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_57_b (Concatenate)   (None, 4, 2, 992)     0           concatenate_56_b[0][0]
#                                                                    conv2d_118_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_57_k (Concatenate)   (None, 4, 2, 992)     0           concatenate_56_k[0][0]
#                                                                    conv2d_118_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_119_b (Batch (None, 4, 2, 992)     3968        concatenate_57_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_119_k (Batch (None, 4, 2, 992)     3968        concatenate_57_k[0][0]
# ____________________________________________________________________________________________________
# activation_119_b (Activation)    (None, 4, 2, 992)     0           batch_normalization_119_b[0][0]
# ____________________________________________________________________________________________________
# activation_119_k (Activation)    (None, 4, 2, 992)     0           batch_normalization_119_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_119_b (Conv2D)            (None, 4, 2, 128)     126976      activation_119_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_119_k (Conv2D)            (None, 4, 2, 128)     126976      activation_119_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_120_b (Batch (None, 4, 2, 128)     512         conv2d_119_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_120_k (Batch (None, 4, 2, 128)     512         conv2d_119_k[0][0]
# ____________________________________________________________________________________________________
# activation_120_b (Activation)    (None, 4, 2, 128)     0           batch_normalization_120_b[0][0]
# ____________________________________________________________________________________________________
# activation_120_k (Activation)    (None, 4, 2, 128)     0           batch_normalization_120_k[0][0]
# ____________________________________________________________________________________________________
# conv2d_120_b (Conv2D)            (None, 4, 2, 32)      36864       activation_120_b[0][0]
# ____________________________________________________________________________________________________
# conv2d_120_k (Conv2D)            (None, 4, 2, 32)      36864       activation_120_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_58_b (Concatenate)   (None, 4, 2, 1024)    0           concatenate_57_b[0][0]
#                                                                    conv2d_120_b[0][0]
# ____________________________________________________________________________________________________
# concatenate_58_k (Concatenate)   (None, 4, 2, 1024)    0           concatenate_57_k[0][0]
#                                                                    conv2d_120_k[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_121_b (Batch (None, 4, 2, 1024)    4096        concatenate_58_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_121_k (Batch (None, 4, 2, 1024)    4096        concatenate_58_k[0][0]
# ____________________________________________________________________________________________________
# activation_121_b (Activation)    (None, 4, 2, 1024)    0           batch_normalization_121_b[0][0]
# ____________________________________________________________________________________________________
# activation_121_k (Activation)    (None, 4, 2, 1024)    0           batch_normalization_121_k[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_1_b (Gl (None, 1024)          0           activation_121_b[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_1_k (Gl (None, 1024)          0           activation_121_k[0][0]
# ____________________________________________________________________________________________________
# dense_2_b (Dense)                (None, 1024)          1049600     global_average_pooling2d_1_b[0][0
# ____________________________________________________________________________________________________
# dense_2_k (Dense)                (None, 1024)          1049600     global_average_pooling2d_1_k[0][0
# ____________________________________________________________________________________________________
# batch_normalization_122_b (Batch (None, 1024)          4096        dense_2_b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_122_k (Batch (None, 1024)          4096        dense_2_k[0][0]
# ____________________________________________________________________________________________________
# activation_122_b (Activation)    (None, 1024)          0           batch_normalization_122_b[0][0]
# ____________________________________________________________________________________________________
# activation_122_k (Activation)    (None, 1024)          0           batch_normalization_122_k[0][0]
# ____________________________________________________________________________________________________
# dense_3_b (Dense)                (None, 128)           131200      activation_122_b[0][0]
# ____________________________________________________________________________________________________
# dense_3_k (Dense)                (None, 128)           131200      activation_122_k[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 256)           0           dense_3_b[0][0]
#                                                                    dense_3_k[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1024)          263168      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 1024)          4096        dense_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 1024)          0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# final_output (Dense)             (None, 128)           131200      activation_1[0][0]
# ====================================================================================================
# Total params: 16,843,264
# Trainable params: 16,669,824
# Non-trainable params: 173,440
# ____________________________________________________________________________________________________

# %%
train_score = {
    'rank1' : {},
    'rank5' : {},
    'rank20' : {},
    'pos_distance' : {},
    'neg_distance' : {},
    'precision' : {},
    'recall' : {},
    'matt_coef' : {},
    'loss' : [],
    'file_name' : {}
}

test_score = {
    'rank1' : {},
    'rank5' : {},
    'rank20' : {},
    'pos_distance' : {},
    'neg_distance' : {},
    'precision' : {},
    'recall' : {},
    'matt_coef' : {},
    'loss' : [],
    'file_name' : {}
}

# %%
epochs = 10
steps_per_epoch = 100

file_root = 'densenet_triplet_merge_3'

history = History()

for era in range(2,6):
    iterations = era * steps_per_epoch * epochs
    
    def step_decay_cont(epoch, init_epoch=epochs*(era - 1), init_lr=0.0003):
        drop = 0.5
        epochs_drop = 10.0
        lrate = init_lr * np.power(drop,  
               np.floor((1 + epoch + init_epoch)**2/epochs_drop**2))
        return lrate

    lrate = LearningRateScheduler(step_decay_cont)

    model.fit_generator(output_batch_generator(train_dict, train_labels), 
                     steps_per_epoch=steps_per_epoch, 
                     epochs=epochs,
                        callbacks=[lrate, history])

    file_name = file_root + '_' + str(iterations) + '.h5'
    model.save('/home/albert/github/tensorflow/models/%s/%s' % (file_root, file_name))
    
    if era == 3 or era == 5:
        train_score = get_score(model, train_dict, train_files, file_root, train_score, iterations, hist=True, train=True)
        test_score = get_score(model, test_dict, test_files, file_root, test_score, iterations, hist=True, train=False)

        for score in [train_score, test_score]:
            plt.figure(figsize=(20,5))
            plt.subplot(1,3,1)
            pos_distance = score['pos_distance'][iterations]
            neg_distance = score['neg_distance'][iterations]
            bins = np.linspace(0, np.max(np.array(pos_distance + neg_distance)), 100)
            plt.hist(pos_distance, bins, alpha=0.5, label='positive pair')
            plt.hist(neg_distance, bins, alpha=0.5, label='negative pair')
            plt.legend(loc='upper right')
            plt.title(str(iterations))

            plt.subplot(1,3,2)
            plt.plot(score['recall'][iterations], score['precision'][iterations])
            plt.xlabel('recall')
            plt.ylabel('precision')
            plt.title(str(iterations))

            plt.subplot(1,3,3)
            plt.plot(np.linspace(0, np.max(np.array(pos_distance + neg_distance)), 101)[1:], 
                     score['matt_coef'][iterations])
            plt.xlabel('dist')
            plt.ylabel('matt_coef')
            plt.title(str(iterations))
            plt.show()

            print 'rank1', score['rank1'][iterations]
            print 'rank5', score['rank5'][iterations]
            print 'rank20', score['rank20'][iterations]
# Out:
# Epoch 1/10
# 100/100 [==============================] - 234s - loss: -60796.1984
# Epoch 2/10
# 100/100 [==============================] - 230s - loss: -63180.7014
# Epoch 3/10
# 100/100 [==============================] - 229s - loss: -74869.3828
# Epoch 4/10
# 100/100 [==============================] - 231s - loss: -85087.2736
# Epoch 5/10
# 100/100 [==============================] - 230s - loss: -96298.7611
# Epoch 6/10
# 100/100 [==============================] - 231s - loss: -99673.3748
# Epoch 7/10
# 100/100 [==============================] - 230s - loss: -108902.9984
# Epoch 8/10
# 100/100 [==============================] - 232s - loss: -114215.0386
# Epoch 9/10
# 100/100 [==============================] - 230s - loss: -112158.6664
# Epoch 10/10
# 100/100 [==============================] - 230s - loss: -120212.9210
# Epoch 1/10
# 100/100 [==============================] - 231s - loss: -125889.5021
# Epoch 2/10
# 100/100 [==============================] - 231s - loss: -124547.1533
# Epoch 3/10
# 100/100 [==============================] - 230s - loss: -128613.2360
# Epoch 4/10
# 100/100 [==============================] - 230s - loss: -126231.5510
# Epoch 5/10
# 100/100 [==============================] - 228s - loss: -133883.5202
# Epoch 6/10
# 100/100 [==============================] - 229s - loss: -129433.8491
# Epoch 7/10
# 100/100 [==============================] - 230s - loss: -126916.1759
# Epoch 8/10
# 100/100 [==============================] - 232s - loss: -131250.3550
# Epoch 9/10
# 100/100 [==============================] - 229s - loss: -131954.1621
# Epoch 10/10
# 100/100 [==============================] - 231s - loss: -131662.1388
# 1000 88.283012867
# 2000 172.513023853
# 3000 259.637112856
# 4000 342.522634983
# 5000 426.244641781
# 6000 512.754593849
# 7000 596.507231951
# 8000 682.438280821
# 9000 768.034083843
# 10000 855.308507919
# 11000 940.61665082
# 12000 1027.54291201
# 1000 82.8542401791
# 2000 169.161998987
# 3000 253.545572042
# 4000 339.137336016
# 5000 424.26615715
# 6000 510.927482128
# 7000 596.147197008
# 8000 681.648688078
# 9000 768.676126003
# 10000 854.053189039
# 11000 940.708383083
# 12000 1024.99434614
# 13000 1112.19530296
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-2c1024cd3f57> in <module>()
#      28     if era == 3 or era == 5:
#      29         train_score = get_score(model, train_dict, train_files, file_root, train_score, iterations, hist=True, train=True)
# ---> 30         test_score = get_score(model, test_dict, test_files, file_root, test_score, iterations, hist=True, train=False)
#      31
#      32         for score in [train_score, test_score]:
#
# <ipython-input-21-a890b733a86a> in get_score(model, files_dict, files_arr, file_root, score, iterations, hist, train)
#      30     score['pos_distance'][iterations] = pos_distance
#      31
# ---> 32     neg_distance = evaluate_dist(model, neg_generator, train=train)
#      33     score['neg_distance'][iterations] = neg_distance
#      34
#
# <ipython-input-17-cf41b4790e4c> in evaluate_dist(model, generator, n_pairs, train)
#       4         pair = generator.next()
#       5         predict = [model.predict({'input_1_b' : misc.imread(pair[i]).reshape(1,128,64,3),
# ----> 6                                   'input_1_k' : overlay_keypoints(pair[i], train=train).reshape(1,128,64,3)}) for i in range(2)]
#       7         dist = distance.cosine(predict[0], predict[1])
#       8         distances.append(dist)
#
# <ipython-input-9-2737c00f1b8b> in overlay_keypoints(img_path, train)
#      23
#      24     if htmp.max() > 0.0:
# ---> 25         htmp = np.array([[3*[j/htmp.max()] for j in row] for row in htmp.tolist()])
#      26     else:
#      27         htmp = np.array([[3*[j] for j in row] for row in htmp.tolist()])
#
# /home/albert/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
test_score = get_score(model, test_dict, test_files, file_root, test_score, 2000, hist=False, train=False)
# Out:
# 1000 89.3191969395
# 2000 182.435804844
# 3000 272.618121862
# 4000 363.776528835
# 5000 454.254688978
# 6000 545.268266916
# 7000 635.16642189
# 8000 726.760790825
# 9000 819.438325882
# 10000 911.825594902
# 11000 1005.5070169
# 12000 1094.64923501
# 13000 1186.54453683

# %%
print test_score['rank20']
# Out:
# {2000: [0.931, 0.938, 0.934]}

# %%
# summarize history for loss
plt.plot(train_score['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
train_rank1_avg = []
train_rank5_avg = []
train_rank20_avg = []
test_rank1_avg = []
test_rank5_avg = []
test_rank20_avg = []

for iterations in train_score['rank5'].keys():
    train_rank1_avg.append(np.average(np.array(train_score['rank1'][iterations])))
    train_rank5_avg.append(np.average(np.array(train_score['rank5'][iterations])))
    train_rank20_avg.append(np.average(np.array(train_score['rank20'][iterations])))
    test_rank1_avg.append(np.average(np.array(test_score['rank1'][iterations])))
    test_rank5_avg.append(np.average(np.array(test_score['rank5'][iterations])))
    test_rank20_avg.append(np.average(np.array(test_score['rank20'][iterations])))

# %%
iterations = 6000
plt.plot(np.arange(1000,iterations+1000,1000), train_rank1_avg, label='train_rank1_avg', )
plt.plot(np.arange(1000,iterations+1000,1000), train_rank5_avg, label='train_rank5_avg', )
plt.plot(np.arange(1000,iterations+1000,1000), train_rank20_avg, label='train_rank20_avg')

plt.plot(np.arange(1000,iterations+1000,1000), test_rank1_avg, label='test_rank1_avg', linestyle='--')
plt.plot(np.arange(1000,iterations+1000,1000), test_rank5_avg, label='test_rank5_avg', linestyle='--')
plt.plot(np.arange(1000,iterations+1000,1000), test_rank20_avg, label='test_rank20_avg', linestyle='--')
plt.legend(loc='lower left')
plt.xlabel('Iteration')
plt.ylabel('Rank')
plt.ylim(-0.5,0.9)
plt.show()

# %%
np.savez('/home/albert/github/tensorflow/models/%s/%s_score_2.npz' % (file_root, file_root), train_score)
np.savez('/home/albert/github/tensorflow/models/%s/%s_test_score_2.npz' % (file_root, file_root), test_score)
